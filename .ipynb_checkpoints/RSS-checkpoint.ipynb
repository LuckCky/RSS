# %%
import feedparser

# %%
feed = feedparser.parse('https://lenta.ru/rss')

# %%
print(feed)
# Out:
# {'encoding': 'utf-8', 'version': 'rss20', 'entries': [{'summary_detail': {'value': 'Генеральный консул Греции в Москве Иоаннис Педиотис заявил, что 80 процентов россиян, обратившихся за долгосрочными визами в июне, получили эти отметки в паспортах. Дипломат добавил, что сейчас подавляющее большинство въездных документов для граждан РФ консульство оформляет на три года.', 'type': 'text/html', 'base': 'https://lenta.ru/rss', 'language': None}, 'guidislink': True, 'title_detail': {'value': 'Генконсул Греции заявил о выдаче большинству россиян долгосрочных виз', 'type': 'text/plain', 'base': 'https://lenta.ru/rss', 'language': None}, 'link': 'https://lenta.ru/news/2016/07/15/longtimevisa/', 'links': [{'href': 'https://lenta.ru/news/2016/07/15/longtimevisa/', 'rel': 'alternate', 'type': 'text/html'}, {'href': 'https://icdn.lenta.ru/images/2016/07/15/17/20160715171927961/pic_d28a1dba02981f0628b91d78fa6cfe91.jpg', 'length': '61455', 'type': 'image/jpeg', 'rel': 'enclosure'}], 'tags': [{'sch
# ...

# %%
feed.feed.title
# Out:
# 'Lenta.ru : Новости'

# %%
feed.entries[0].published
# Out:
# 'Fri, 15 Jul 2016 16:06:00 +0300'
